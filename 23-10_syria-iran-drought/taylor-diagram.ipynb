# %% [markdown]
# # **Taylor diagrams for spatial patterns**

# %%
import sys; sys.path.append('/rds/general/user/cb2714/home/'); from wwa import *
from taylorDiagram import TaylorDiagram

# %%
xr.open_dataset("../00_WWA_project_folder/ephemeral/synda/data/WAS-22/MIROC-MIROC5/r1i1p1/RegCM4-7/pr/pr_WAS-22_MIROC-MIROC5_historical_r1i1p1_ICTP-RegCM4-7_v0_day_19700101-19701231.nc")
# Out:
# <xarray.Dataset>
# Dimensions:    (y: 337, x: 429, time: 365, bnds: 2)
# Coordinates:
#     lat        (y, x) float64 ...
#     lon        (y, x) float64 ...
#   * time       (time) object 1970-01-01 12:00:00 ... 1970-12-31 12:00:00
#   * x          (x) float64 -5.35e+06 -5.325e+06 -5.3e+06 ... 5.325e+06 5.35e+06
#   * y          (y) float64 -4.2e+06 -4.175e+06 -4.15e+06 ... 4.175e+06 4.2e+06
# Dimensions without coordinates: bnds
# Data variables:
#     crs        |S1 ...
#     pr         (time, y, x) float32 ...
#     time_bnds  (time, bnds) object ...
# Attributes: (12/163)
#     project_id:                                      CORDEX
#     ipcc_scenario_code:                              HISTORICAL
#     institute_id:                                    ORNL
#     note:                                            The domain is larger tha...
#     comment:                                         RegCM CORDEX SAsia25 run
#     experiment:                                      WAS-22
# ...

# %%
cartopy.crs.RotatedPole(pole_longitude=-123.34, pole_latitude = 79.95)

# %%
cartopy.crs.ObliqueMercator(central_longitude=70.0, central_latitude=13.0, false_easting=-12500.0, false_northing=-12500.0, scale_factor=1.0, azimuth=89.999999, globe=None)
# Out:
# <Derived Projected CRS: +proj=omerc +lat_0=13.00 +alpha=89.999999 +lonc=70 ...>
# Name: unknown
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unknown
# - method: Hotine Oblique Mercator (variant B)
# Datum: unknown
# - Ellipsoid: unknown
# - Prime Meridian: Greenwich
